# %%
import numpy as np
import matplotlib.pyplot as plt 
import IPython.display as ipd # This is a library that allows us to play audio samples in Jupyter
import sys
sys.path.append('..')
from SyntheticCurves import *

"""
Finish basic example with figure 8 and listen to it.  You may have to adjust the base frequency w0

Play around with this idea. Try sqaure waves instead of sinusoids, try it on different curves
"""



t = np.linspace(0, 12, 44100)
X = np.zeros((len(t), 3))
X[:, 0] = t
X[:, 1] = 2*t
X[:, 2] = 4*t
X = getVivianiFigure8(5, t)

#np.random.seed(0)
X = applyRandomRigidTransformation(X, True)
plt.subplot(211)
plt.scatter(X[:, 0], X[:, 1],X[:, 2], c=t)
plt.axis('equal')
w = 5
# sin(2pi * w * t)
plt.subplot(212)

x = np.sin(2*(w*2)*np.pi*X[:, 0])
#x = np.sign(x)
plt.plot(t, x)

y = np.sin(2*(w*4)*np.pi*X[:, 1])
plt.plot(t, y)

z = np.sin(2*(w*3)*np.pi*X[:, 2])
plt.plot(t,z)

plt.show()

fs = 44100
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
xSpace = np.zeros(int(fs*0.000001)) ## Put a tenth of a second space
z = np.concatenate((x, xSpace, y, xSpace, z, xSpace, y, xSpace, x))
#z = x + y
ipd.Audio(z, rate=fs/10)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
